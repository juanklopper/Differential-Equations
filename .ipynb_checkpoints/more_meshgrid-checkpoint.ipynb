# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x, y = np.meshgrid(np.arange(-10, 11, 1), np.arange(0, 11, 1))
U = x ** 2
V = 3 * np.sqrt(y)

plt.figure(figsize=(12,12), dpi=300)
plt.quiver(U, V)

plt.show();
